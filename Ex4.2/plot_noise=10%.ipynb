# %%
import numpy as np
S_num_store=np.load("./IARFM/noise=10%/S_num_store_10%.npy")

# %%
# import matplotlib.pyplot as plt
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')

# %%
import numpy as np
import matplotlib.pyplot as plt

# 创建数据
x = np.linspace(-0.3, 0.3, 301)
y = np.linspace(-0.3, 0.3, 301)
X, Y = np.meshgrid(x, y,indexing='ij')

# 创建图形
plt.figure(figsize=(8, 6))
S_num_10=S_num_store[-1]
contour_fill = plt.contourf(X, Y, S_num_10, levels=20, cmap='rainbow', alpha=1, vmin=np.nanmin(S_num_10), vmax=np.nanmax(S_num_10))

# # 在上面绘制等高线
# CS = plt.contour(X, Y, S_num_10, levels=10, colors='k', linewidths=0.8)
# plt.clabel(CS, inline=True, fontsize=10, fmt='%1.2f')

# 添加颜色条 - 与3D图保持一致
cbar = plt.colorbar(contour_fill, shrink=1, aspect=10)
cbar.ax.tick_params(labelsize=16)

# 如果知道3D图的z轴范围，可以设置相同的范围
# cbar.set_clim(vmin=你的最小值, vmax=你的最大值)

# 标签和刻度设置
plt.xlabel('$x_1$', fontsize=30)
plt.ylabel('$x_2$', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=18)


# 美观设置
plt.gca().set_facecolor('white')  # 设置背景为白色，增强对比度
plt.tight_layout()
plt.savefig('./IARFM/noise=10%/S_num_10.pdf', dpi=300)
plt.show()

# %%
def ana_S(y):
    y0=y[:,0]
    y1=y[:,1]
    return 1.1*np.exp(-200*((y0-0.01)**2+(y1-0.12)**2))-100*(y1**2-y0**2)*np.exp(-90*(y0**2+y1**2))
XX = np.array([X.ravel(), Y.ravel()]).T
S_true=ana_S(XX).reshape(X.shape)

# %%
import numpy as np
import matplotlib.pyplot as plt


# 创建图形
plt.figure(figsize=(8, 6))

# 绘制等高线图 - 使用更饱和的颜色
# 使用contourf填充背景色，使整体颜色更深
contour_fill = plt.contourf(X, Y, S_true, levels=20, cmap='rainbow', alpha=1, vmin=np.nanmin(S_num_10), vmax=np.nanmax(S_num_10))

# 在上面绘制等高线
# CS = plt.contour(X, Y, S_true, levels=10, colors='k', linewidths=0.8)
# plt.clabel(CS, inline=True, fontsize=10, fmt='%1.2f')

# 添加颜色条 - 与3D图保持一致
cbar = plt.colorbar(contour_fill, shrink=1, aspect=10)
cbar.ax.tick_params(labelsize=16)

# 如果知道3D图的z轴范围，可以设置相同的范围
# cbar.set_clim(vmin=你的最小值, vmax=你的最大值)

# 标签和刻度设置
plt.xlabel('$x_1$', fontsize=30)
plt.ylabel('$x_2$', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=18)



# 美观设置
plt.gca().set_facecolor('white')  # 设置背景为白色，增强对比度

plt.tight_layout()
plt.savefig('./IARFM/noise=10%/S_true.pdf', dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# 创建图形
plt.figure(figsize=(8, 6))

# 绘制等高线图 - 使用更饱和的颜色
# 使用contourf填充背景色，使整体颜色更深
contour_fill = plt.contourf(X, Y, np.abs(S_true-S_num_10), levels=20, cmap='rainbow', alpha=1)



# 添加颜色条 - 与3D图保持一致
cbar = plt.colorbar(contour_fill, shrink=1, aspect=10)
cbar.ax.tick_params(labelsize=16)

# 如果知道3D图的z轴范围，可以设置相同的范围
# cbar.set_clim(vmin=你的最小值, vmax=你的最大值)

# 标签和刻度设置
plt.xlabel('$x_1$', fontsize=30)
plt.ylabel('$x_2$', fontsize=30)
plt.tick_params(axis='both', which='major', labelsize=18)


# 美观设置
plt.gca().set_facecolor('white')  # 设置背景为白色，增强对比度
plt.tight_layout()
plt.savefig('./IARFM/noise=10%/abs_S.pdf', dpi=300)
plt.show()
